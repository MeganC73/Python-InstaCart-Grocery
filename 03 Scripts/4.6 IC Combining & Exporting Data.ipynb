# %% [markdown]
# # Practice Exercises

# %%
# Import Libraries 
import pandas as pd 
import numpy as np 
import os

# %%
path = r'C:\Users\Megan\Documents\CareerFoundry\Unit 4\InstaCart Python Project'

# %%
# Define a data dictionary containing January 2020 data 

data_1 = {'customer_id':['6732', '767', '890', '635'],
         'month':['Jan-20', 'Jan-20', 'Jan-20', 'Jan-20'], 
         'purchased_meat':[0, 10, 5, 3], 
         'purchased_alcohol':[2, 4, 14, 0], 
         'purchased_snacks': [15, 3, 2, 6]}

# %%
# Define a data dictionary containing February 2020 data

data_2 = {'customer_id':['6732', '767', '890', '635'], 
        'month':['Feb-20', 'Feb-20', 'Feb-20', 'Feb-20'], 
        'purchased_meat':[0, 10, 5, 3], 
        'purchased_alcohol':[2, 4, 14, 0],
        'purchased_snacks': [15, 3, 2, 6]}

# %%
# Convert the dictionary into data frame 

df = pd.DataFrame(data_1,index=[0, 1, 2, 3])
df_1 = pd.DataFrame(data_2,index=[0,1,2,3])

# %%
df
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  2                15
# 1         767  Jan-20              10                  4                 3
# 2         890  Jan-20               5                 14                 2
# 3         635  Jan-20               3                  0                 6

# %%
df_1
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %%
# Create list of both datasets and concatenate them using default (long) format
frames = [df, df_1]
df_concat = pd.concat(frames)

# %%
# Check output
df_concat
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  2                15
# 1         767  Jan-20              10                  4                 3
# 2         890  Jan-20               5                 14                 2
# 3         635  Jan-20               3                  0                 6
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %%
#Check data types to make sure it is a list 
type(frames)
# Out:
# list

# %%
# Concatenate frames in wide format
df_concat_2 = pd.concat(frames, axis = 1)

# %%
# Check output 
df_concat_2
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  2                15
# 1         767  Jan-20              10                  4                 3
# 2         890  Jan-20               5                 14                 2
# 3         635  Jan-20               3                  0                 6
#
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %%
# Append dataframes 
df_appended = df.append(df_1)
# Out:
# C:\Users\Megan\AppData\Local\Temp\ipykernel_20156\2334807040.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_appended = df.append(df_1)

# %%
df_appended
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  2                15
# 1         767  Jan-20              10                  4                 3
# 2         890  Jan-20               5                 14                 2
# 3         635  Jan-20               3                  0                 6
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %%
# Create dataframe with different number of columns from df 

data_3 = {'customer_id':['6732', '767', '890', '635'], 
         'month':['Jan-20', 'Jan-20', 'Jan-20', 'Jan-20'], 
          'days_purchased_on':[0, 13, 3, 4]}

# %%
# Convert data_3 dictionary into dataframe  
df_2 = pd.DataFrame(data_3,index=[0,1,2,3])

# %%
# Check output 
df_2
# Out:
#   customer_id   month  days_purchased_on
# 0        6732  Jan-20                  0
# 1         767  Jan-20                 13
# 2         890  Jan-20                  3
# 3         635  Jan-20                  4

# %%
# Try appending 
df_append_test = df.append(df_2)
# Out:
# C:\Users\Megan\AppData\Local\Temp\ipykernel_20156\1691425731.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_test = df.append(df_2)

# %%
df_append_test
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20             0.0                2.0              15.0
# 1         767  Jan-20            10.0                4.0               3.0
# 2         890  Jan-20             5.0               14.0               2.0
# 3         635  Jan-20             3.0                0.0               6.0
# 0        6732  Jan-20             NaN                NaN               NaN
# 1         767  Jan-20             NaN                NaN               NaN
# 2         890  Jan-20             NaN                NaN               NaN
# 3         635  Jan-20             NaN                NaN               NaN
#
#    days_purchased_on
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 0                0.0
# 1               13.0
# 2                3.0
# 3                4.0

# %%
# Merge df and df_2 dataframes on the customer_id column
df_merged = df.merge(df_2, on = 'customer_id')

# %%
# Check output 
df_merged
# Out:
#   customer_id month_x  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  2                15
# 1         767  Jan-20              10                  4                 3
# 2         890  Jan-20               5                 14                 2
# 3         635  Jan-20               3                  0                 6
#
#   month_y  days_purchased_on
# 0  Jan-20                  0
# 1  Jan-20                 13
# 2  Jan-20                  3
# 3  Jan-20                  4

# %%
df_merged = df.merge(df_2, on = ['customer_id', 'month'])

# %%
df_merged
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  2                15
# 1         767  Jan-20              10                  4                 3
# 2         890  Jan-20               5                 14                 2
# 3         635  Jan-20               3                  0                 6
#
#    days_purchased_on
# 0                  0
# 1                 13
# 2                  3
# 3                  4

# %%
# Check which columns match 
df_merged = df.merge(df_2, on = ['customer_id', 'month'], indicator = True)

# %%
# Check output
df_merged
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  2                15
# 1         767  Jan-20              10                  4                 3
# 2         890  Jan-20               5                 14                 2
# 3         635  Jan-20               3                  0                 6
#
#    days_purchased_on _merge
# 0                  0   both
# 1                 13   both
# 2                  3   both
# 3                  4   both

# %%
df_merged['_merge'].value_counts()
# Out:
# both          4
# left_only     0
# right_only    0
# Name: _merge, dtype: int64

# %% [markdown]
# ## Merge InstaCart Data

# %%
# Import new dataset 
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'order_products_prior.csv'), index_col = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20156\3073853045.py in <module>
#       1 # Import new dataset
# ----> 2 df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'order_products_prior.csv'), index_col = False)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
