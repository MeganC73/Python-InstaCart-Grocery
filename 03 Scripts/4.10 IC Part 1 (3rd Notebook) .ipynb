# %%
# Import libraries 
import pandas as pd 
import numpy as np 
import os

# %%
# Create path 
path = r"C:\Users\Megan\Documents\CareerFoundry\Unit 4\InstaCart Python Project"

# %%
# Import df 
df_new = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data','4.10_new.pkl'))

# %%
# Import departments df  
df_dept = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'departments_wrangled.csv'), index_col = False)

# %%
df_dept.head()
# Out:
#    Unnamed: 0 department
# 0           1     frozen
# 1           2      other
# 2           3     bakery
# 3           4    produce
# 4           5    alcohol

# %%
# Rename column 
df_dept.rename(columns = {'Unnamed: 0' : 'department_id'}, inplace = True)

# %%
# Check output 
df_dept.head(10)
# Out:
#    department_id       department
# 0              1           frozen
# 1              2            other
# 2              3           bakery
# 3              4          produce
# 4              5          alcohol
# 5              6    international
# 6              7        beverages
# 7              8             pets
# 8              9  dry goods pasta
# 9             10             bulk

# %%
df_new.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'order_day_of_week',
#        'order_hour', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', '_merge', 'product_name', 'aisle_id',
#        'department_id', 'prices', 'price_range_loc', 'Busiest Days',
#        'busiest_period_of_day', 'max_order', 'loyalty_flag', 'mean_price',
#        'spending_flag', 'days_median', 'order_frequency_flag', 'gender',
#        'state', 'age', '#_dependents', 'marital_status', 'income',
#        'geographic_region', 'max_orders', 'activity_flag', 'age_flag',
#        'income_class', 'family_size'],
#       dtype='object')

# %%
# Merge dataframes on department_id column 
df_merged = df_new.merge(df_dept, on = 'department_id')

# %%
# Check value counts 
df_merged['department'].value_counts(dropna = False)
# Out:
# produce            9079273
# dairy eggs         5177182
# snacks             2766406
# beverages          2571901
# frozen             2121731
# pantry             1782705
# bakery             1120828
# canned goods       1012074
# deli               1003834
# dry goods pasta     822136
# household           699857
# meat seafood        674781
# breakfast           670850
# personal care       424306
# babies              410392
# international       255991
# alcohol             144627
# pets                 93060
# missing              64768
# other                34411
# bulk                 33451
# Name: department, dtype: int64

# %%
# Combine age_flag and income_class  
df_merged['cust_profile'] = df_merged['age_flag'] + df_merged['income_class']

# %%
df_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour  \
# 0   2539329        1             1                  2           8
# 1   2398795        1             2                  3           7
# 2    473747        1             3                  3          12
# 3   2254736        1             4                  4           7
# 4    431534        1             5                  4          15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                    11.0         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#    ... marital_status  income  geographic_region  max_orders  \
# ...

# %%
# Export df to save RAM
df_merged.to_pickle(os.path.join(path,'02 Data','Prepared Data','4.10_new.pkl'))
